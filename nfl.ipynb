# %%
import pandas as pd

# %%
df = pd.read_csv('./nfl_box_score.csv')

# %%
pd.DataFrame(df).to_excel('nfl_data.xlsx')

# %%
excel = pd.read_excel('./NFL data.xlsx')

# %%
nfl = df.drop(columns=['Blank'])

# %%
df
# Out:
#        Game ID schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0            0      9/2/1966             1966             1             False
# 1            1      9/3/1966             1966             1             False
# 2            2      9/4/1966             1966             1             False
# 3            3      9/9/1966             1966             2             False
# 4            4     9/10/1966             1966             1             False
# ...        ...           ...              ...           ...               ...
# 13783    13783      1/7/2024             2023            18             False
# 13784    13784      1/7/2024             2023            18             False
# 13785    13785      1/7/2024             2023            18             False
# 13786    13786      1/7/2024             2023            18             False
# 13787    13787      1/7/2024             2023            18             False
#
# ...

# %%
pd.DataFrame(nfl).to_csv('nfl_scores_and_lines.csv')
